# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Employees.csv")

# %%
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                     2
# 1              Poor             High                Low                     3
# 2              Good             High                Low                     0
# 3              Good             High               High                     1
# 4              Fair        Very High            Average                     0
#
# ...

# %%
df.columns
# Out:
# Index(['Employee ID', 'Age', 'Gender', 'Years at Company', 'Job Role',
#        'Monthly Income', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Number of Promotions', 'Overtime',
#        'Distance from Home', 'Education Level', 'Marital Status',
#        'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure',
#        'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities',
#        'Company Reputation', 'Employee Recognition', 'Attrition'],
#       dtype='object')

# %%
df.shape
# Out:
# (59598, 24)

# %%
df.isnull().sum()
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(df['Years at Company'])
# Out:
# <Axes: >

# %%
sns.distplot(df['Years at Company'])
# Out:
# C:\Users\ayazulhaq\AppData\Local\Temp\ipykernel_10112\2753516721.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Years at Company'])
# <Axes: xlabel='Years at Company', ylabel='Density'>

# %%
def capping_outliers(column):
    q1=df['Years at Company'].quantile(0.25)
    q3=df['Years at Company'].quantile(0.75)
    iqr=q3-q1
    upper=q3+1.5*iqr
    lower=q1-1.5*iqr
    if column > upper:
        return upper
    elif column < lower:
        return lower
    else:
        return column

# %%
df['Years at Company']=df['Years at Company'].apply(capping_outliers)

# %%
sns.boxplot(df['Years at Company'])
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Employee ID', 'Age', 'Gender', 'Years at Company', 'Job Role',
#        'Monthly Income', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Number of Promotions', 'Overtime',
#        'Distance from Home', 'Education Level', 'Marital Status',
#        'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure',
#        'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities',
#        'Company Reputation', 'Employee Recognition', 'Attrition'],
#       dtype='object')

# %%
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male              19.0   Education            5390
# 1        64756   59  Female               4.0       Media            5534
# 2        30257   24  Female              10.0  Healthcare            8159
# 3        65791   36  Female               7.0   Education            3989
# 4        65026   56    Male              41.0   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                     2
# 1              Poor             High                Low                     3
# 2              Good             High                Low                     0
# 3              Good             High               High                     1
# 4              Fair        Very High            Average                     0
#
# ...

# %%
sns.boxplot(df['Monthly Income'])
# Out:
# <Axes: >

# %%
def capping_outliers(column):
    q1=df['Monthly Income'].quantile(0.25)
    q3=df['Monthly Income'].quantile(0.75)
    iqr=q3-q1
    upper=q3+1.5*iqr
    lower=q1-1.5*iqr
    if column > upper:
        return upper
    elif column < lower:
        return lower
    else:
        return column

# %%
df['Monthly Income']=df['Monthly Income'].apply(capping_outliers)

# %%
sns.boxplot(x=df['Monthly Income'])
# Out:
# <Axes: xlabel='Monthly Income'>

# %%
sns.distplot(df['Number of Promotions'])
# Out:
# C:\Users\ayazulhaq\AppData\Local\Temp\ipykernel_10112\985706347.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Number of Promotions'])
# <Axes: xlabel='Number of Promotions', ylabel='Density'>

# %%
sns.boxplot(df['Number of Promotions'])
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59598 entries, 0 to 59597
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               59598 non-null  int64
#  1   Age                       59598 non-null  int64
#  2   Gender                    59598 non-null  object
#  3   Years at Company          59598 non-null  float64
#  4   Job Role                  59598 non-null  object
#  5   Monthly Income            59598 non-null  float64
#  6   Work-Life Balance         59598 non-null  object
#  7   Job Satisfaction          59598 non-null  object
#  8   Performance Rating        59598 non-null  object
#  9   Number of Promotions      59598 non-null  int64
#  10  Overtime                  59598 non-null  object
#  11  Distance from Home        59598 non-null  int64
#  12  Education Level           59598 non-null  object
# ...

# %%
sns.distplot(df['Distance from Home'])
# Out:
# C:\Users\ayazulhaq\AppData\Local\Temp\ipykernel_10112\514512221.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Distance from Home'])
# <Axes: xlabel='Distance from Home', ylabel='Density'>

# %%
sns.boxplot(df['Distance from Home'])
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59598 entries, 0 to 59597
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               59598 non-null  int64
#  1   Age                       59598 non-null  int64
#  2   Gender                    59598 non-null  object
#  3   Years at Company          59598 non-null  float64
#  4   Job Role                  59598 non-null  object
#  5   Monthly Income            59598 non-null  float64
#  6   Work-Life Balance         59598 non-null  object
#  7   Job Satisfaction          59598 non-null  object
#  8   Performance Rating        59598 non-null  object
#  9   Number of Promotions      59598 non-null  int64
#  10  Overtime                  59598 non-null  object
#  11  Distance from Home        59598 non-null  int64
#  12  Education Level           59598 non-null  object
# ...

# %%
sns.distplot(df['Number of Dependents'])
# Out:
# C:\Users\ayazulhaq\AppData\Local\Temp\ipykernel_10112\4023947211.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Number of Dependents'])
# <Axes: xlabel='Number of Dependents', ylabel='Density'>

# %%
sns.boxplot(df['Number of Dependents'])
# Out:
# <Axes: >

# %%
sns.distplot(df['Company Tenure'])
# Out:
# C:\Users\ayazulhaq\AppData\Local\Temp\ipykernel_10112\2807768668.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Company Tenure'])
# <Axes: xlabel='Company Tenure', ylabel='Density'>

# %%
sns.boxplot(df['Company Tenure'])
# Out:
# <Axes: >

# %%
df.to_csv("cleaned_employ_Data.csv")

# %%
df=pd.read_csv("cleaned_employ_Data.csv")

# %% [markdown]
# # Starting the EDA

# %% [markdown]
# <h3> Starting the Analysis </h3>

# %%
df.describe()
# Out:
#          Unnamed: 0   Employee ID           Age  Years at Company  \
# count  59598.000000  59598.000000  59598.000000      59598.000000
# mean   29798.500000  37227.118729     38.565875         15.744908
# std    17204.605009  21519.150028     12.079673         11.219977
# min        0.000000      1.000000     18.000000          1.000000
# 25%    14899.250000  18580.250000     28.000000          7.000000
# 50%    29798.500000  37209.500000     39.000000         13.000000
# 75%    44697.750000  55876.750000     49.000000         23.000000
# max    59597.000000  74498.000000     59.000000         47.000000
#
#        Monthly Income  Number of Promotions  Distance from Home  \
# count    59598.000000          59598.000000        59598.000000
# mean      7301.954998              0.832578           50.007651
# std       2150.031037              0.994991           28.466459
# min       1316.000000              0.000000            1.000000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Employee ID', 'Age', 'Gender', 'Years at Company',
#        'Job Role', 'Monthly Income', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Number of Promotions', 'Overtime',
#        'Distance from Home', 'Education Level', 'Marital Status',
#        'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure',
#        'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities',
#        'Company Reputation', 'Employee Recognition', 'Attrition'],
#       dtype='object')

# %% [markdown]
# <h4> As we know employee ID have not any positive affect so, we have to remove them </h4>

# %%
df.drop("Employee ID",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0           0   31    Male              19.0   Education          5390.0
# 1           1   59  Female               4.0       Media          5534.0
# 2           2   24  Female              10.0  Healthcare          8159.0
# 3           3   36  Female               7.0   Education          3989.0
# 4           4   56    Male              41.0   Education          4821.0
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                     2
# 1              Poor             High                Low                     3
# 2              Good             High                Low                     0
# 3              Good             High               High                     1
# 4              Fair        Very High            Average                     0
#
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# Stayed    31260
# Left      28338
# Name: count, dtype: int64

# %%
sns.barplot(x=df['Attrition'],y=df['Age'],hue=df['Gender'])
# Out:
# <Axes: xlabel='Attrition', ylabel='Age'>

# %% [markdown]
# <h3> The average age for a person who left is 37 and for the person who stayed is 39 the percentage of a female are more as compared to men </h3>

# %%
sns.barplot(x=df['Attrition'],y=df['Years at Company'],hue=df['Job Role'])
# Out:
# <Axes: xlabel='Attrition', ylabel='Years at Company'>

# %% [markdown]
# <h3> 15 years is the average age where the people left </h3>

# %%
sns.lineplot(x=df['Attrition'],y=df['Age'])
# Out:
# <Axes: xlabel='Attrition', ylabel='Age'>

# %%
sns.lineplot(x=df['Attrition'],y=df['Years at Company'])
# Out:
# <Axes: xlabel='Attrition', ylabel='Years at Company'>

# %%
sns.lineplot(x=df['Attrition'],y=df['Monthly Income'])
# Out:
# <Axes: xlabel='Attrition', ylabel='Monthly Income'>

# %%
df.groupby("Attrition")['Monthly Income'].mean()
# Out:
# Attrition
# Left      7276.149552
# Stayed    7325.348305
# Name: Monthly Income, dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0  Employee ID  Age  Gender  Years at Company    Job Role  \
# 0           0         8410   31    Male              19.0   Education
# 1           1        64756   59  Female               4.0       Media
# 2           2        30257   24  Female              10.0  Healthcare
# 3           3        65791   36  Female               7.0   Education
# 4           4        65026   56    Male              41.0   Education
#
#    Monthly Income Work-Life Balance Job Satisfaction Performance Rating  ...  \
# 0          5390.0         Excellent           Medium            Average  ...
# 1          5534.0              Poor             High                Low  ...
# 2          8159.0              Good             High                Low  ...
# 3          3989.0              Good             High               High  ...
# 4          4821.0              Fair        Very High            Average  ...
#
#    Number of Dependents Job Level  Company Size Company Tenure Remote Work  \
# ...

# %%
left_data=df[df['Attrition']=='Left']
stayed_data=df[df['Attrition']=="Stayed"]

# %%
left_data
# Out:
#        Unnamed: 0  Employee ID  Age  Gender  Years at Company    Job Role  \
# 5               5        24368   38  Female               3.0  Technology
# 6               6        64970   47    Male              23.0   Education
# 9               9        15944   24  Female               1.0  Healthcare
# 10             10        29972   30  Female              12.0   Education
# 11             11         9063   29  Female               6.0  Healthcare
# ...           ...          ...  ...     ...               ...         ...
# 59590       59590        16024   23    Male              10.0  Healthcare
# 59591       59591        60264   42    Male              10.0  Technology
# 59593       59593        37195   50  Female              12.0   Education
# 59594       59594         6266   18    Male               4.0  Healthcare
# 59596       59596          861   23    Male               8.0   Education
#
#        Monthly Income Work-Life Balance Job Satisfaction Performance Rating  \
# ...

# %%
left_data['Work-Life Balance'].value_counts()
# Out:
# Work-Life Balance
# Fair         10370
# Good          9137
# Poor          4992
# Excellent     3839
# Name: count, dtype: int64

# %%
left_data['Job Satisfaction'].value_counts()
# Out:
# Job Satisfaction
# High         13489
# Very High     6405
# Medium        5356
# Low           3088
# Name: count, dtype: int64

# %%
sns.histplot(left_data['Age'],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# <h3> The maximum ammount of People who left the job are below 20 </h3>

# %%
left_data.head()
# Out:
#     Unnamed: 0  Employee ID  Age  Gender  Years at Company    Job Role  \
# 5            5        24368   38  Female               3.0  Technology
# 6            6        64970   47    Male              23.0   Education
# 9            9        15944   24  Female               1.0  Healthcare
# 10          10        29972   30  Female              12.0   Education
# 11          11         9063   29  Female               6.0  Healthcare
#
#     Monthly Income Work-Life Balance Job Satisfaction Performance Rating  ...  \
# 5           9977.0              Fair             High      Below Average  ...
# 6           3681.0              Fair             High               High  ...
# 9           7319.0              Poor             High            Average  ...
# 10          5443.0              Good             High            Average  ...
# 11          8950.0              Poor           Medium                Low  ...
#
# ...

# %%
left_data['Gender'].value_counts()
# Out:
# Gender
# Female    14279
# Male      14059
# Name: count, dtype: int64

# %%
sns.histplot(x=df['Years at Company'])
# Out:
# <Axes: xlabel='Years at Company', ylabel='Count'>

# %% [markdown]
# <h3> Whenever the  years in company are increases the lefting ratio decreases </h3>

# %%
left_data.head()
# Out:
#     Unnamed: 0  Employee ID  Age  Gender  Years at Company    Job Role  \
# 5            5        24368   38  Female               3.0  Technology
# 6            6        64970   47    Male              23.0   Education
# 9            9        15944   24  Female               1.0  Healthcare
# 10          10        29972   30  Female              12.0   Education
# 11          11         9063   29  Female               6.0  Healthcare
#
#     Monthly Income Work-Life Balance Job Satisfaction Performance Rating  ...  \
# 5           9977.0              Fair             High      Below Average  ...
# 6           3681.0              Fair             High               High  ...
# 9           7319.0              Poor             High            Average  ...
# 10          5443.0              Good             High            Average  ...
# 11          8950.0              Poor           Medium                Low  ...
#
# ...

# %%
sns.histplot(left_data['Monthly Income'])
# Out:
# <Axes: xlabel='Monthly Income', ylabel='Count'>

# %%
left_data['Performance Rating'].value_counts()
# Out:
# Performance Rating
# Average          16527
# High              5477
# Below Average     4637
# Low               1697
# Name: count, dtype: int64

# %%
left_data['Overtime'].value_counts()
sns.countplot(x=df['Overtime'])
# Out:
# <Axes: xlabel='Overtime', ylabel='count'>

# %%
left_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28338 entries, 5 to 59596
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28338 non-null  int64
#  1   Employee ID               28338 non-null  int64
#  2   Age                       28338 non-null  int64
#  3   Gender                    28338 non-null  object
#  4   Years at Company          28338 non-null  float64
#  5   Job Role                  28338 non-null  object
#  6   Monthly Income            28338 non-null  float64
#  7   Work-Life Balance         28338 non-null  object
#  8   Job Satisfaction          28338 non-null  object
#  9   Performance Rating        28338 non-null  object
#  10  Number of Promotions      28338 non-null  int64
#  11  Overtime                  28338 non-null  object
#  12  Distance from Home        28338 non-null  int64
# ...

# %%
left_data['Number of Promotions'].value_counts()
# Out:
# Number of Promotions
# 0    14658
# 1     7336
# 2     5341
# 3      823
# 4      180
# Name: count, dtype: int64

# %%
plt.figure(figsize=(18,5))
sns.countplot(x=left_data['Number of Promotions'])
# Out:
# <Axes: xlabel='Number of Promotions', ylabel='count'>

# %%
sns.histplot(left_data['Number of Promotions'])
# Out:
# <Axes: xlabel='Number of Promotions', ylabel='Count'>

# %% [markdown]
# <h3> The number of promotion is of the major issue </h3>

# %%
left_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28338 entries, 5 to 59596
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28338 non-null  int64
#  1   Employee ID               28338 non-null  int64
#  2   Age                       28338 non-null  int64
#  3   Gender                    28338 non-null  object
#  4   Years at Company          28338 non-null  float64
#  5   Job Role                  28338 non-null  object
#  6   Monthly Income            28338 non-null  float64
#  7   Work-Life Balance         28338 non-null  object
#  8   Job Satisfaction          28338 non-null  object
#  9   Performance Rating        28338 non-null  object
#  10  Number of Promotions      28338 non-null  int64
#  11  Overtime                  28338 non-null  object
#  12  Distance from Home        28338 non-null  int64
# ...

# %%
sns.histplot(left_data['Distance from Home'],kde=True)
# Out:
# <Axes: xlabel='Distance from Home', ylabel='Count'>

# %%
left_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28338 entries, 5 to 59596
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28338 non-null  int64
#  1   Employee ID               28338 non-null  int64
#  2   Age                       28338 non-null  int64
#  3   Gender                    28338 non-null  object
#  4   Years at Company          28338 non-null  float64
#  5   Job Role                  28338 non-null  object
#  6   Monthly Income            28338 non-null  float64
#  7   Work-Life Balance         28338 non-null  object
#  8   Job Satisfaction          28338 non-null  object
#  9   Performance Rating        28338 non-null  object
#  10  Number of Promotions      28338 non-null  int64
#  11  Overtime                  28338 non-null  object
#  12  Distance from Home        28338 non-null  int64
# ...

# %%
sns.countplot(x=left_data['Education Level'])
# Out:
# <Axes: xlabel='Education Level', ylabel='count'>

# %% [markdown]
# <h3> Most of the employees who left have a bachelor degree </h3>

# %%
left_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28338 entries, 5 to 59596
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28338 non-null  int64
#  1   Employee ID               28338 non-null  int64
#  2   Age                       28338 non-null  int64
#  3   Gender                    28338 non-null  object
#  4   Years at Company          28338 non-null  float64
#  5   Job Role                  28338 non-null  object
#  6   Monthly Income            28338 non-null  float64
#  7   Work-Life Balance         28338 non-null  object
#  8   Job Satisfaction          28338 non-null  object
#  9   Performance Rating        28338 non-null  object
#  10  Number of Promotions      28338 non-null  int64
#  11  Overtime                  28338 non-null  object
#  12  Distance from Home        28338 non-null  int64
# ...

# %%
left_data['Marital Status'].value_counts()
# Out:
# Marital Status
# Single      13923
# Married     10811
# Divorced     3604
# Name: count, dtype: int64

# %%
left_data['Job Level'].value_counts()
# Out:
# Job Level
# Entry     15082
# Mid       10823
# Senior     2433
# Name: count, dtype: int64

# %%
sns.histplot(left_data['Job Level'])
# Out:
# <Axes: xlabel='Job Level', ylabel='Count'>

# %% [markdown]
# <h3> Entry and Mid range have high value </h3>

# %%
left_data['Company Size'].value_counts()
# Out:
# Company Size
# Medium    13855
# Small      8945
# Large      5538
# Name: count, dtype: int64

# %%
left_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28338 entries, 5 to 59596
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28338 non-null  int64
#  1   Employee ID               28338 non-null  int64
#  2   Age                       28338 non-null  int64
#  3   Gender                    28338 non-null  object
#  4   Years at Company          28338 non-null  float64
#  5   Job Role                  28338 non-null  object
#  6   Monthly Income            28338 non-null  float64
#  7   Work-Life Balance         28338 non-null  object
#  8   Job Satisfaction          28338 non-null  object
#  9   Performance Rating        28338 non-null  object
#  10  Number of Promotions      28338 non-null  int64
#  11  Overtime                  28338 non-null  object
#  12  Distance from Home        28338 non-null  int64
# ...

# %%
sns.histplot(left_data['Company Tenure'])
# Out:
# <Axes: xlabel='Company Tenure', ylabel='Count'>

# %%
left_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28338 entries, 5 to 59596
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28338 non-null  int64
#  1   Employee ID               28338 non-null  int64
#  2   Age                       28338 non-null  int64
#  3   Gender                    28338 non-null  object
#  4   Years at Company          28338 non-null  float64
#  5   Job Role                  28338 non-null  object
#  6   Monthly Income            28338 non-null  float64
#  7   Work-Life Balance         28338 non-null  object
#  8   Job Satisfaction          28338 non-null  object
#  9   Performance Rating        28338 non-null  object
#  10  Number of Promotions      28338 non-null  int64
#  11  Overtime                  28338 non-null  object
#  12  Distance from Home        28338 non-null  int64
# ...

# %%
left_data['Remote Work'].value_counts()
# Out:
# Remote Work
# No     25514
# Yes     2824
# Name: count, dtype: int64

# %%
sns.countplot(x=left_data['Leadership Opportunities'])
# Out:
# <Axes: xlabel='Leadership Opportunities', ylabel='count'>

# %%
sns.countplot(x=df['Innovation Opportunities'])
# Out:
# <Axes: xlabel='Innovation Opportunities', ylabel='count'>

# %% [markdown]
# <h3> Lack of Leadership and Innovation opportunities is also one of the major factor </h3>

# %%
left_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28338 entries, 5 to 59596
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                28338 non-null  int64
#  1   Employee ID               28338 non-null  int64
#  2   Age                       28338 non-null  int64
#  3   Gender                    28338 non-null  object
#  4   Years at Company          28338 non-null  float64
#  5   Job Role                  28338 non-null  object
#  6   Monthly Income            28338 non-null  float64
#  7   Work-Life Balance         28338 non-null  object
#  8   Job Satisfaction          28338 non-null  object
#  9   Performance Rating        28338 non-null  object
#  10  Number of Promotions      28338 non-null  int64
#  11  Overtime                  28338 non-null  object
#  12  Distance from Home        28338 non-null  int64
# ...

# %%
left_data['Company Reputation'].value_counts()
# Out:
# Company Reputation
# Good         12774
# Poor          6799
# Fair          6138
# Excellent     2627
# Name: count, dtype: int64

# %%
left_data['Employee Recognition'].value_counts()
# Out:
# Employee Recognition
# Low          11363
# Medium        8604
# High          7004
# Very High     1367
# Name: count, dtype: int64

# %%
sns.countplot(x=left_data['Employee Recognition'])
# Out:
# <Axes: xlabel='Employee Recognition', ylabel='count'>

# %% [markdown]
# <h3> Employees who are low recognized have the high probibility of being left out </h3>

# %% [markdown]
# <h1> Feature Engineering and Selection </h1>

# %%
df.head()
# Out:
#    Unnamed: 0  Employee ID  Age  Gender  Years at Company    Job Role  \
# 0           0         8410   31    Male              19.0   Education
# 1           1        64756   59  Female               4.0       Media
# 2           2        30257   24  Female              10.0  Healthcare
# 3           3        65791   36  Female               7.0   Education
# 4           4        65026   56    Male              41.0   Education
#
#    Monthly Income Work-Life Balance Job Satisfaction Performance Rating  ...  \
# 0          5390.0         Excellent           Medium            Average  ...
# 1          5534.0              Poor             High                Low  ...
# 2          8159.0              Good             High                Low  ...
# 3          3989.0              Good             High               High  ...
# 4          4821.0              Fair        Very High            Average  ...
#
#    Number of Dependents Job Level  Company Size Company Tenure Remote Work  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59598 entries, 0 to 59597
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                59598 non-null  int64
#  1   Employee ID               59598 non-null  int64
#  2   Age                       59598 non-null  int64
#  3   Gender                    59598 non-null  object
#  4   Years at Company          59598 non-null  float64
#  5   Job Role                  59598 non-null  object
#  6   Monthly Income            59598 non-null  float64
#  7   Work-Life Balance         59598 non-null  object
#  8   Job Satisfaction          59598 non-null  object
#  9   Performance Rating        59598 non-null  object
#  10  Number of Promotions      59598 non-null  int64
#  11  Overtime                  59598 non-null  object
#  12  Distance from Home        59598 non-null  int64
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      32739
# Female    26859
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['Gender']=lb.fit_transform(df['Gender'])

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 1    32739
# 0    26859
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59598 entries, 0 to 59597
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                59598 non-null  int64
#  1   Employee ID               59598 non-null  int64
#  2   Age                       59598 non-null  int64
#  3   Gender                    59598 non-null  int32
#  4   Years at Company          59598 non-null  float64
#  5   Job Role                  59598 non-null  object
#  6   Monthly Income            59598 non-null  float64
#  7   Work-Life Balance         59598 non-null  object
#  8   Job Satisfaction          59598 non-null  object
#  9   Performance Rating        59598 non-null  object
#  10  Number of Promotions      59598 non-null  int64
#  11  Overtime                  59598 non-null  object
#  12  Distance from Home        59598 non-null  int64
# ...

# %%
df['Job Role']=lb.fit_transform(df['Job Role'])
df['Work-Life Balance']=lb.fit_transform(df['Work-Life Balance'])
df['Job Satisfaction']=lb.fit_transform(df['Job Satisfaction'])
df['Performance Rating']=lb.fit_transform(df['Performance Rating'])
df['Overtime']=lb.fit_transform(df['Overtime'])
df['Education Level']=lb.fit_transform(df['Education Level'])
df['Marital Status']=lb.fit_transform(df['Marital Status'])
df['Job Level']=lb.fit_transform(df['Job Level'])
df['Company Size']=lb.fit_transform(df['Company Size'])
df['Attrition']=lb.fit_transform(df['Attrition'])
df['Company Tenure']=lb.fit_transform(df['Company Tenure'])
df['Employee Recognition']=lb.fit_transform(df['Employee Recognition'])
df['Innovation Opportunities']=lb.fit_transform(df['Innovation Opportunities'])
df['Leadership Opportunities']=lb.fit_transform(df['Leadership Opportunities'])
df['Company Reputation']=lb.fit_transform(df['Company Reputation'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59598 entries, 0 to 59597
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                59598 non-null  int64
#  1   Employee ID               59598 non-null  int64
#  2   Age                       59598 non-null  int64
#  3   Gender                    59598 non-null  int32
#  4   Years at Company          59598 non-null  float64
#  5   Job Role                  59598 non-null  int32
#  6   Monthly Income            59598 non-null  float64
#  7   Work-Life Balance         59598 non-null  int32
#  8   Job Satisfaction          59598 non-null  int32
#  9   Performance Rating        59598 non-null  int32
#  10  Number of Promotions      59598 non-null  int64
#  11  Overtime                  59598 non-null  int32
#  12  Distance from Home        59598 non-null  int64
#  13  Education Level           59598 non-null  int32
# ...

# %%
df['Remote Work']=lb.fit_transform(df['Remote Work'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59598 entries, 0 to 59597
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                59598 non-null  int64
#  1   Employee ID               59598 non-null  int64
#  2   Age                       59598 non-null  int64
#  3   Gender                    59598 non-null  int32
#  4   Years at Company          59598 non-null  float64
#  5   Job Role                  59598 non-null  int32
#  6   Monthly Income            59598 non-null  float64
#  7   Work-Life Balance         59598 non-null  int32
#  8   Job Satisfaction          59598 non-null  int32
#  9   Performance Rating        59598 non-null  int32
#  10  Number of Promotions      59598 non-null  int64
#  11  Overtime                  59598 non-null  int32
#  12  Distance from Home        59598 non-null  int64
#  13  Education Level           59598 non-null  int32
# ...

# %%
df.corr()['Attrition']
# Out:
# Unnamed: 0                 -0.001071
# Employee ID                -0.002674
# Age                         0.048900
# Gender                      0.101825
# Years at Company            0.064941
# Job Role                    0.007316
# Monthly Income              0.011428
# Work-Life Balance          -0.063083
# Job Satisfaction           -0.046653
# Performance Rating         -0.032219
# Number of Promotions        0.080591
# Overtime                   -0.055664
# Distance from Home         -0.095570
# Education Level             0.050722
# Marital Status             -0.229559
# Number of Dependents        0.078337
# Job Level                   0.313642
# Company Size               -0.026188
# Company Tenure              0.030285
# Remote Work                 0.220447
# Leadership Opportunities    0.010193
# Innovation Opportunities    0.021536
# Company Reputation         -0.038146
# Employee Recognition        0.000002
# Attrition                   1.000000
# ...

# %%
plt.figure(figsize=(18,9))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %% [markdown]
# <h1> Remove the feature that are negative correlated </h1>

# %% [markdown]
# df.drop("Work-Life Balance",axis=1,inplace=True)
# df.drop("Job Satisfaction",axis=1,inplace=True)
# df.drop("Performance Rating",axis=1,inplace=True)

# %%
df.drop("Distance from Home",axis=1,inplace=True)
df.drop("Overtime",axis=1,inplace=True)
df.drop("Marital Status",axis=1,inplace=True)
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.corr()['Attrition']
# Out:
# Employee ID                -0.002674
# Age                         0.048900
# Gender                      0.101825
# Years at Company            0.064941
# Job Role                    0.007316
# Monthly Income              0.011428
# Number of Promotions        0.080591
# Education Level             0.050722
# Number of Dependents        0.078337
# Job Level                   0.313642
# Company Size               -0.026188
# Company Tenure              0.030285
# Remote Work                 0.220447
# Leadership Opportunities    0.010193
# Innovation Opportunities    0.021536
# Company Reputation         -0.038146
# Employee Recognition        0.000002
# Attrition                   1.000000
# Name: Attrition, dtype: float64

# %%
df.drop("Company Size",axis=1,inplace=True)
df.drop("Company Reputation",axis=1,inplace=True)

# %%
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company  Job Role  Monthly Income  \
# 0         8410   31       1              19.0         0          5390.0
# 1        64756   59       0               4.0         3          5534.0
# 2        30257   24       0              10.0         2          8159.0
# 3        65791   36       0               7.0         0          3989.0
# 4        65026   56       1              41.0         0          4821.0
#
#    Number of Promotions  Education Level  Number of Dependents  Job Level  \
# 0                     2                0                     0          1
# 1                     3                3                     3          1
# 2                     0                1                     3          1
# 3                     1                2                     2          1
# 4                     0                2                     0          2
#
#    Company Tenure  Remote Work  Leadership Opportunities  \
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.corr()['Attrition']
# Out:
# Employee ID                -0.002674
# Age                         0.048900
# Gender                      0.101825
# Years at Company            0.064941
# Job Role                    0.007316
# Monthly Income              0.011428
# Number of Promotions        0.080591
# Education Level             0.050722
# Number of Dependents        0.078337
# Job Level                   0.313642
# Company Tenure              0.030285
# Remote Work                 0.220447
# Leadership Opportunities    0.010193
# Innovation Opportunities    0.021536
# Employee Recognition        0.000002
# Attrition                   1.000000
# Name: Attrition, dtype: float64

# %%
df.drop("Employee ID",axis=1,inplace=True)
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
sd=StandardScaler()

# %%
X=df.drop("Attrition",axis=1)
y=df['Attrition']
X_scaled=sd.fit_transform(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3,random_state=45)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()

# %%
lg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
ypre=lg.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ac=accuracy_score(ypre,y_test)

# %%
ac
# Out:
# 0.6756711409395973

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gr=GradientBoostingClassifier(n_estimators=200,learning_rate=0.1)

# %%
X=df.drop("Attrition",axis=1)
y=df["Attrition"]
gr.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(n_estimators=200)

# %%
ypre=gr.predict(X_test)

# %%
accuracy_score(ypre,y_test)
# Out:
# 0.6924496644295302

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

models = {
    "GradientBoostingClassifier": GradientBoostingClassifier(),
    
}


params = {
    "GradientBoostingClassifier": {
        "n_estimators": [50, 100, 150, 200],
        "learning_rate": np.linspace(0.1, 1.0, 10)
    },

}

for model_name, current_model in models.items():
    try:
        params_grid = params[model_name]  
        gr = GridSearchCV(current_model, params_grid, cv=5, scoring="accuracy")
        gr.fit(X_train, y_train)
        print(f"Model: {model_name}")
        print(f"Best Score: {gr.best_score_}")
        print(f"Best Parameters: {gr.best_params_}")
        print("-" * 30)  
    except KeyError:
        print(f"Warning: No parameter grid found for model {model_name}. Skipping.")
# Out:
# Model: GradientBoostingClassifier
# Best Score: 0.6940886424097041
# Best Parameters: {'learning_rate': 0.1, 'n_estimators': 100}
# ------------------------------

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier


models = {
    "KNeighborsClassifier": KNeighborsClassifier(),
    
}

# Define parameter grid for each model (adjust hyperparameters as needed)
params = {
     'KNeighborsClassifier': {
        'n_neighbors': range(1, 21),
        'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
    },
    
}

for model_name, current_model in models.items():
    try:
        params_grid = params[model_name]  # Access model-specific parameter grid
        gr = GridSearchCV(current_model, params_grid, cv=5, scoring="accuracy")
        gr.fit(X_train, y_train)
        print(f"Model: {model_name}")
        print(f"Best Score: {gr.best_score_}")
        print(f"Best Parameters: {gr.best_params_}")
        print("-" * 30)  # Optional separator for clarity
    except KeyError:
        print(f"Warning: No parameter grid found for model {model_name}. Skipping.")
# Out:
# Model: KNeighborsClassifier
# Best Score: 0.6629032508292299
# Best Parameters: {'algorithm': 'auto', 'n_neighbors': 19}
# ------------------------------

# %%
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier


models = {
    "AdaBoostClassifier": AdaBoostClassifier(),
    
}


params = {
    'AdaBoostClassifier': {
        'n_estimators': range(50, 201, 50),
        'learning_rate': np.linspace(0.1, 1.0, 10)
    }
}

for model_name, current_model in models.items():
    try:
        params_grid = params[model_name]  # Access model-specific parameter grid
        gr = GridSearchCV(current_model, params_grid, cv=5, scoring="accuracy")
        gr.fit(X_train, y_train)
        print(f"Model: {model_name}")
        print(f"Best Score: {gr.best_score_}")
        print(f"Best Parameters: {gr.best_params_}")
        print("-" * 30)  # Optional separator for clarity
    except KeyError:
        print(f"Warning: No parameter grid found for model {model_name}. Skipping.")
# Out:
# Model: AdaBoostClassifier
# Best Score: 0.6952392185754841
# Best Parameters: {'learning_rate': 0.1, 'n_estimators': 150}
# ------------------------------

# %%
models = {
    "RFM": RandomForestClassifier(),

}

params = {
    'RFM': {
        'n_estimators': range(50, 201, 50),
        'criterion': ['gini','entropy']
    }
}

for model_name, current_model in models.items():
    try:
        params_grid = params[model_name]  
        gr = GridSearchCV(current_model, params_grid, cv=5, scoring="accuracy")
        gr.fit(X_train, y_train)
        print(f"Model: {model_name}")
        print(f"Best Score: {gr.best_score_}")
        print(f"Best Parameters: {gr.best_params_}")
        print("-" * 30)
    except KeyError:
        print(f"Warning: No parameter grid found for model {model_name}. Skipping.")
# Out:
# Model: RFM
# Best Score: 0.6826786948233051
# Best Parameters: {'criterion': 'gini', 'n_estimators': 200}
# ------------------------------

# %% [markdown]
# <h1>So the Maximum accuracy has been given by Adaboost which is 70 </h1>

# %% [markdown]
# <h2> So, Now lets do it without removing the negative correlated features and with Standard Sclaer and Minmax Scaler </h2>

# %%
df=pd.read_csv("cleaned_employ_Data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Employee ID  Age  Gender  Years at Company    Job Role  \
# 0           0         8410   31    Male              19.0   Education
# 1           1        64756   59  Female               4.0       Media
# 2           2        30257   24  Female              10.0  Healthcare
# 3           3        65791   36  Female               7.0   Education
# 4           4        65026   56    Male              41.0   Education
#
#    Monthly Income Work-Life Balance Job Satisfaction Performance Rating  ...  \
# 0          5390.0         Excellent           Medium            Average  ...
# 1          5534.0              Poor             High                Low  ...
# 2          8159.0              Good             High                Low  ...
# 3          3989.0              Good             High               High  ...
# 4          4821.0              Fair        Very High            Average  ...
#
#    Number of Dependents Job Level  Company Size Company Tenure Remote Work  \
# ...

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)
df.drop("Employee ID",axis=1,inplace=True)

# %%
from sklearn.preprocessing import MinMaxScaler,LabelEncoder
lb=LabelEncoder()
mn=MinMaxScaler()

# %%
df['Job Role']=lb.fit_transform(df['Job Role'])
df['Work-Life Balance']=lb.fit_transform(df['Work-Life Balance'])
df['Job Satisfaction']=lb.fit_transform(df['Job Satisfaction'])
df['Performance Rating']=lb.fit_transform(df['Performance Rating'])
df['Overtime']=lb.fit_transform(df['Overtime'])
df['Education Level']=lb.fit_transform(df['Education Level'])
df['Marital Status']=lb.fit_transform(df['Marital Status'])
df['Job Level']=lb.fit_transform(df['Job Level'])
df['Company Size']=lb.fit_transform(df['Company Size'])
df['Attrition']=lb.fit_transform(df['Attrition'])
df['Company Tenure']=lb.fit_transform(df['Company Tenure'])
df['Employee Recognition']=lb.fit_transform(df['Employee Recognition'])
df['Innovation Opportunities']=lb.fit_transform(df['Innovation Opportunities'])
df['Leadership Opportunities']=lb.fit_transform(df['Leadership Opportunities'])
df['Company Reputation']=lb.fit_transform(df['Company Reputation'])
df['Gender']=lb.fit_transform(df['Gender'])

# %%
df['Remote Work']=lb.fit_transform(df['Remote Work'])

# %%
X=df.drop("Attrition",axis=1)

# %%
y=df['Attrition']

# %%
minmax=MinMaxScaler()

# %%
X_scaled=minmax.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.25,random_state=56)

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from lightgbm import LGBMClassifier

# %%
classifier_grid = {
    'KNeighborsClassifier': {
        'n_neighbors': range(1, 21),
        'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
    },
    'DecisionTreeClassifier': {
        'max_depth': range(2, 21),
        'criterion': ['gini', 'entropy']
    },
    'RandomForestClassifier': {
        'n_estimators': range(10, 101, 10),
        'max_depth': range(2, 21),
        'criterion': ['gini', 'entropy']
    },
    'AdaBoostClassifier': {
        'n_estimators': range(50, 201, 50),
        'learning_rate': np.linspace(0.1, 1.0, 10)
    }
}

# %%
classifiers = []
for clf_name, param_grid in classifier_grid.items():
    classifier = eval(clf_name)()  
    gscv = GridSearchCV(estimator=classifier, param_grid=param_grid, cv=5, scoring='accuracy')
    classifiers.append((clf_name, gscv))

for name, clf in classifiers:
    clf.fit(X_train, y_train)
    print(f"\nBest parameters for {name}: {clf.best_params_}")
    print(f"Best score for {name}: {clf.best_score_}")
# Out:
# Best parameters for KNeighborsClassifier: {'algorithm': 'auto', 'n_neighbors': 19}
# Best score for KNeighborsClassifier: 0.6987335189813735
#
# Best parameters for DecisionTreeClassifier: {'criterion': 'entropy', 'max_depth': 9}
# Best score for DecisionTreeClassifier: 0.7249763735464807
#
# Best parameters for RandomForestClassifier: {'criterion': 'entropy', 'max_depth': 11, 'n_estimators': 60}
# Best score for RandomForestClassifier: 0.7480422966199193
#
# Best parameters for AdaBoostClassifier: {'learning_rate': 0.6, 'n_estimators': 200}
# Best score for AdaBoostClassifier: 0.7597654623069159

# %%
classifier_grid={
    'GaussianNB': {},
    "LGBMClassifier":{
        'learning_rate':np.linspace(0.1, 1.0, 10),
        'n_estimators':[50,100,150,200]
    
}
}

# %%
classifiers = []
for clf_name, param_grid in classifier_grid.items():
    classifier = eval(clf_name)()  
    gscv = GridSearchCV(estimator=classifier, param_grid=param_grid, cv=5, scoring='accuracy')
    classifiers.append((clf_name, gscv))

for name, clf in classifiers:
    clf.fit(X_train, y_train)
    print(f"\nBest parameters for {name}: {clf.best_params_}")
    print(f"Best score for {name}: {clf.best_score_}")
# Out:
# Best parameters for GaussianNB: {}
# Best score for GaussianNB: 0.7072352431956791
# [LightGBM] [Info] Number of positive: 18792, number of negative: 16966
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002137 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 630
# [LightGBM] [Info] Number of data points in the train set: 35758, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.525533 -> initscore=0.102220
# [LightGBM] [Info] Start training from score 0.102220
# [LightGBM] [Info] Number of positive: 18792, number of negative: 16966
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001268 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 630
# ...

# %% [markdown]
# <h1> Lets add some more data and Use Minmax Scaler </h1>

# %%
df2=pd.read_csv("Addition_of_extra_data.csv")

# %%
df1=pd.read_csv("cleaned_employ_Data.csv")

# %%
df=pd.concat([df1,df2])

# %%
df['Job Role']=lb.fit_transform(df['Job Role'])
df['Work-Life Balance']=lb.fit_transform(df['Work-Life Balance'])
df['Job Satisfaction']=lb.fit_transform(df['Job Satisfaction'])
df['Performance Rating']=lb.fit_transform(df['Performance Rating'])
df['Overtime']=lb.fit_transform(df['Overtime'])
df['Education Level']=lb.fit_transform(df['Education Level'])
df['Marital Status']=lb.fit_transform(df['Marital Status'])
df['Job Level']=lb.fit_transform(df['Job Level'])
df['Company Size']=lb.fit_transform(df['Company Size'])
df['Attrition']=lb.fit_transform(df['Attrition'])
df['Company Tenure']=lb.fit_transform(df['Company Tenure'])
df['Employee Recognition']=lb.fit_transform(df['Employee Recognition'])
df['Innovation Opportunities']=lb.fit_transform(df['Innovation Opportunities'])
df['Leadership Opportunities']=lb.fit_transform(df['Leadership Opportunities'])
df['Company Reputation']=lb.fit_transform(df['Company Reputation'])
df['Gender']=lb.fit_transform(df['Gender'])
df['Remote Work']=lb.fit_transform(df['Remote Work'])

# %%
from sklearn.model_selection import train_test_split

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)
df.drop("Employee ID",axis=1,inplace=True)

# %%
X=df.drop("Attrition",axis=1)
y=df['Attrition']
X_scaled=minmax.fit_transform(X)

# %%
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.25,random_state=56)

# %%
lgbm_model=LGBMClassifier(objective='binary', metric='accuracy')  


param_grid = {
    'learning_rate': [0.01, 0.1, 1],
    'num_leaves': [31, 100, 200],
    'max_depth': [-1, 5, 10]  # -1 for unlimited
}


grid_search = GridSearchCV(estimator=lgbm_model, param_grid=param_grid, cv=5, scoring='accuracy')


grid_search.fit(X_train, y_train)


lgbm_model = grid_search.best_estimator_

# Evaluate the best model on the test set
y_pred = lgbm_model.predict(X_test)
# Out:
# [LightGBM] [Info] Number of positive: 23510, number of negative: 21188
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002126 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 634
# [LightGBM] [Info] Number of data points in the train set: 44698, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.525974 -> initscore=0.103991
# [LightGBM] [Info] Start training from score 0.103991
# [LightGBM] [Info] Number of positive: 23509, number of negative: 21189
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001904 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 634
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7537181208053692

# %%
ada_model=AdaBoostClassifier()  

param_grid = {
    'learning_rate': [0.01, 0.1, 1],
    'n_estimators': [50, 100,150,80,170,200],
      
}

grid_search = GridSearchCV(estimator=ada_model, param_grid=param_grid, cv=5, scoring='accuracy')

grid_search.fit(X_train, y_train)

best_model = grid_search.best_estimator_

y_pred = best_model.predict(X_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7581744966442953

# %%
rfc_model=RandomForestClassifier()  


param_grid = {
    'criterion': ['gini','entropy'],
    'n_estimators': [31, 100, 200],
    'max_depth': [-1, 5, 10]  # -1 for unlimited
}

grid_search = GridSearchCV(estimator=rfc_model, param_grid=param_grid, cv=5, scoring='accuracy')


grid_search.fit(X_train, y_train)

rfc = grid_search.best_estimator_

y_pred =rfc.predict(X_test)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 30 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7452348993288591

# %%
Gradient_model=GradientBoostingClassifier() 

param_grid = {
        "n_estimators": [50, 100, 150, 200],
        "learning_rate": np.linspace(0.1, 1.0, 10)
    
}


grid_search = GridSearchCV(estimator=Gradient_model, param_grid=param_grid, cv=5, scoring='accuracy')


grid_search.fit(X_train, y_train)


rfc = grid_search.best_estimator_

y_pred =rfc.predict(X_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7581744966442953

# %%
Best_model=AdaBoostClassifier(learning_rate=0.6,n_estimators=200)

# %%
Best_model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.6, n_estimators=200)

# %%
ypre=Best_model.predict(X_test)

# %%
round(accuracy_score(ypre,y_test),2)
# Out:
# 0.76

# %%
import pickle
model="model.txt"

# %%
with open(model, 'wb') as model_file:
  
  pickle.dump(Best_model, model_file)

print(f"AdaBoost model saved to '{model}'.")
# Out:
# AdaBoost model saved to 'model.txt'.

# %%
from sklearn.metrics import confusion_matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt



sns.heatmap(confusion_matrix(ypre,y_test), annot=True, fmt='.2f')  
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

plt.show()

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(ypre,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75      8886
#            1       0.77      0.77      0.77      9739
#
#     accuracy                           0.76     18625
#    macro avg       0.76      0.76      0.76     18625
# weighted avg       0.76      0.76      0.76     18625
